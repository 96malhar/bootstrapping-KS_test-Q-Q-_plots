# %% [markdown]
# # K-S Test

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline

#generate a gaussian r.v X
x = stats.norm.rvs(size=1000);
sns.set_style('whitegrid')
sns.kdeplot(x, bw=0.5)
plt.show()

# %%
stats.kstest(x, 'norm')
# Out:
# KstestResult(statistic=0.02125279884412762, pvalue=0.7570800478427543)

# %%
# Y ~ Continous Uniform Distribution(0,1)
y = np.random.uniform(0,1,10000);
sns.kdeplot(y, bw=0.1)
plt.show()

# %%
stats.kstest(y, 'norm')
# Out:
# KstestResult(statistic=0.5000115485037755, pvalue=0.0)
